# %% [markdown]
# # More Tests

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy
from brian2 import *

# %%
# functions for plotting
def plot_output_colored(t, v, u, I, save_fig=False, file_name='test.png'):
    fig, axes = plt.subplots(4, sharey=True, figsize=(12, 12))
    
    axes[0].plot(t, v, label='v')
    axes[0].plot(t, u, label='u')
    axes[0].plot(t, I, label='I')
    axes[0].axhline(30, ls='-', c='C3', lw=2, label='v=30')
    axes[0].set_xlabel('Time (ms)')
    axes[0].set_ylabel('v, u, I')
    axes[0].set_title('Trimodal')
    axes[0].legend()
    
    axes[1].plot(t, v, label='v')
    axes[1].plot(t, u, label='u')
    axes[1].plot(t, I, label='I')
    axes[1].axhline(30, ls='-', c='C3', lw=2, label='v=30')
    axes[1].set_xlim([1000, 2000])
    axes[1].set_xlabel('Time (ms)')
    axes[1].set_ylabel('v, u, I')
    axes[1].set_title('Tonic')
    axes[1].legend()
    
    axes[2].plot(t, v, label='v')
    axes[2].plot(t, u, label='u')
    axes[2].plot(t, I, label='I')
    axes[2].axhline(30, ls='-', c='C3', lw=2, label='v=30')
    axes[2].set_xlim([7000, 8000])
    axes[2].set_xlabel('Time (ms)')
    axes[2].set_ylabel('v, u, I')
    axes[2].set_title('Burst')
    axes[2].legend()
    
    axes[3].plot(t, v, label='v')
    axes[3].plot(t, u, label='u')
    axes[3].plot(t, I, label='I')
    axes[3].axhline(30, ls='-', c='C3', lw=2, label='v=30')
    axes[3].set_xlim([13000, 14000])
    axes[3].set_xlabel('Time (ms)')
    axes[3].set_ylabel('v, u, I')
    axes[3].set_title('Quiescent')
    axes[3].legend()
    
    fig.tight_layout()
    
    if save_fig:
        plt.savefig('outputs/' + file_name, bbox_inches='tight')
        plt.close(fig)
    else:
        plt.show()
    
    
def plot_output(t, v, u, save_fig=False, file_name='test.png'):
    fig, axes = plt.subplots(4, sharey=True, figsize=(12, 12))
    
    axes[0].plot(t, v, 'k-', label='v')
    axes[0].plot(t, u, 'k:', label='u')
    axes[0].set_xlabel('Time (ms)')
    axes[0].set_ylabel('v, u')
    axes[0].set_title('Trimodal')
    axes[0].legend()
    
    axes[1].plot(t, v, 'k-', label='v')
    axes[1].plot(t, u, 'k:', label='u')
    axes[1].set_xlim([1000, 2000])
    axes[1].set_xlabel('Time (ms)')
    axes[1].set_ylabel('v, u')
    axes[1].set_title('Tonic')
    axes[1].legend()
    
    axes[2].plot(t, v, 'k-', label='v')
    axes[2].plot(t, u, 'k:', label='u')
    axes[2].set_xlim([7000, 8000])
    axes[2].set_xlabel('Time (ms)')
    axes[2].set_ylabel('v, u')
    axes[2].set_title('Burst')
    axes[2].legend()
    
    axes[3].plot(t, v, 'k-', label='v')
    axes[3].plot(t, u, 'k:', label='u')
    axes[3].set_xlim([13000, 14000])
    axes[3].set_xlabel('Time (ms)')
    axes[3].set_ylabel('v, u')
    axes[3].set_title('Quiescent')
    axes[3].legend()
    
    fig.tight_layout()
    
    if save_fig:
        plt.savefig('outputs/' + file_name, bbox_inches='tight')
        plt.close(fig)
    else:
        plt.show()
    
    
def plot_output_simple(t, v, u, save_fig=False, file_name='test.png'):
    plt.figure(figsize=(12, 4))
    plt.plot(t, v, 'k-', label='v')
    plt.plot(t, u, 'k:', label='u')
    plt.xlabel('Time (ms)')
    plt.ylabel('v, u')
    plt.title('Trimodal')
    plt.legend()
    
    if save_fig:
        plt.savefig('outputs/' + file_name, bbox_inches='tight')
        plt.close()
    else:
        plt.show()

# %% [markdown]
# ### Alcohol Inhibition (Complex, Modified 2)

# %%
# total run duration 90s
# desired quiescent 10s
# desired bimodal 25s
# desired tonic 15s

def IZH_inh_modified2(
    fI='int(t>100*ms)*10', 
    V=-65, 
    tau=0.25, 
    duration_t=5000,
    duration_b=7000,
    duration_q=8000,
    plot_colored=False, #True,
    e_in=0, 
    e_max=0.45,
    Ra=0,
    Rb=0,
    RI=0,
    save_output=False,
    output_file='test.png',
):
        
    defaultclock.dt = tau*ms
    tau = tau/ms
    
    eqs = '''
    dv/dt = int(t>duration/10)*tau*(0.04*v**2+5*v+140-u+((1-RI*(e_in/e_max))*I)) : 1
    du/dt = int(t>duration/10)*tau*((1-Ra*(e_in/e_max))*a)*(((1-Rb*(e_in/e_max))*b)*v-u) : 1
    I : 1
    '''

    # Create a NeuronGroup with one neuron using previous equations
    G = NeuronGroup(1, eqs, threshold='v>=30', reset='v=c; u+=d', method='euler')
    G.v = V
    G.u = 0.2*V
    
    M = StateMonitor(G, ('v', 'u', 'I'), record=0)
    S = SpikeMonitor(G)
    
    @network_operation(dt=1*ms)
    def change_I():
        G.I = fI
    
    print(f'Running model...')
    a = 0.02
    b = 0.2
    c = -65
    d = 0.5 # ISI_tonic = 30ms
    
    Ra = 0.2
    Rb = 0.6
    RI = 0.4
    duration = 10000*ms
    run(duration)
    
    Ra = 0.1
    Rb = 0.4
    RI = 0.3
    duration = 10000*ms
    run(duration)
    
    Ra = 0.2
    Rb = 0.6
    RI = 0.4
    duration = 10000*ms
    run(duration)
    
    Ra = 0.1
    Rb = 0.4
    RI = 0.3
    duration = 20000*ms
    run(duration)
    
    Ra = 0.15
    Rb = 0.5
    RI = 0.35
    duration = 10000*ms
    run(duration)
    
    Ra = 0.2
    Rb = 0.6
    RI = 0.4
    duration = 20000*ms
    run(duration)
   
    # Plotting
    """
    plt.figure()
    plt.plot(M.t/ms, M.Ra[0], 'k-', label='Ra')
    plt.plot(M.t/ms, M.Rb[0], 'k--', label='Rb')
    plt.plot(M.t/ms, M.RI[0], 'k:', label='RI')
    plt.xlabel('Time')
    plt.ylabel('Ratio')
    plt.legend()
    plt.show()
    """
    
    """
    print('Creating plot.')
    if plot_colored:
        plot_output_colored(M.t/ms, M.v[0], M.u[0], M.I[0], save_fig=save_output, file_name=output_file)
    else:
        plot_output_simple(M.t/ms, M.v[0], M.u[0], save_fig=save_output, file_name=output_file)
    """
        
    return(np.diff(S.t))

# %%
inh_vals = [0.05, 0.10, 0.15, 0.20, 0.30, 0.35, 0.40, 0.45]
ISIs = []

for val in inh_vals:
    print(f'Testing e = {val}')
    ISI = IZH_inh_modified2(e_in=val, save_output=False)
    ISIs.append(ISI)
    print('')
# Out:
# Testing e = 0.05
# Running model...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 6
#       4 for val in inh_vals:
#       5     print(f'Testing e = {val}')
# ----> 6     ISI = IZH_inh_modified2(e_in=val, save_output=False)
#       7     ISIs.append(ISI)
#       8     print('')
#
# Cell In[4], line 84, in IZH_inh_modified2(fI, V, tau, duration_t, duration_b, duration_q, plot_colored, e_in, e_max, Ra, Rb, RI, save_output, output_file)
#      82 RI = 0.4
#      83 duration = 20000*ms
# ---> 84 run(duration)
#      86 # Plotting
#      87 """
#      88 plt.figure()
#      89 plt.plot(M.t/ms, M.Ra[0], 'k-', label='Ra')
#    (...)
#      95 plt.show()
#      96 """
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\units\fundamentalunits.py:2780, in check_units.<locals>.do_check_units.<locals>.new_f(*args, **kwds)
#    2770             error_message = (
#    2771                 f"Function '{f.__name__}' "
#    2772                 "expected a quantitity with unit "
#    2773                 f"{unit} for argument '{k}' but got "
#    2774                 f"'{value}'"
#    2775             )
#    2776             raise DimensionMismatchError(
#    2777                 error_message, get_dimensions(newkeyset[k])
#    2778             )
# -> 2780 result = f(*args, **kwds)
#    2781 if "result" in au:
#    2782     if isinstance(au["result"], Callable) and au["result"] != bool:
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\core\magic.py:407, in run(duration, report, report_period, namespace, profile, level)
#     334 @check_units(duration=second, report_period=second)
#     335 def run(
#     336     duration,
#    (...)
#     341     level=0,
#     342 ):
#     343     """
#     344     run(duration, report=None, report_period=10*second, namespace=None, level=0)
#     345
#    (...)
#     405         intended use. See `MagicNetwork` for more details.
#     406     """
# --> 407     return magic_network.run(
#     408         duration,
#     409         report=report,
#     410         report_period=report_period,
#     411         namespace=namespace,
#     412         profile=profile,
#     413         level=2 + level,
#     414     )
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\core\magic.py:248, in MagicNetwork.run(self, duration, report, report_period, namespace, profile, level)
#     238 def run(
#     239     self,
#     240     duration,
#    (...)
#     245     level=0,
#     246 ):
#     247     self._update_magic_objects(level=level + 1)
# --> 248     Network.run(
#     249         self,
#     250         duration,
#     251         report=report,
#     252         report_period=report_period,
#     253         namespace=namespace,
#     254         profile=profile,
#     255         level=level + 1,
#     256     )
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\core\base.py:335, in device_override.<locals>.device_override_decorator.<locals>.device_override_decorated_function(*args, **kwds)
#     333     return getattr(curdev, name)(*args, **kwds)
#     334 else:
# --> 335     return func(*args, **kwds)
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\units\fundamentalunits.py:2780, in check_units.<locals>.do_check_units.<locals>.new_f(*args, **kwds)
#    2770             error_message = (
#    2771                 f"Function '{f.__name__}' "
#    2772                 "expected a quantitity with unit "
#    2773                 f"{unit} for argument '{k}' but got "
#    2774                 f"'{value}'"
#    2775             )
#    2776             raise DimensionMismatchError(
#    2777                 error_message, get_dimensions(newkeyset[k])
#    2778             )
# -> 2780 result = f(*args, **kwds)
#    2781 if "result" in au:
#    2782     if isinstance(au["result"], Callable) and au["result"] != bool:
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\core\network.py:1221, in Network.run(self, duration, report, report_period, namespace, profile, level)
#    1219     for obj in active_objects:
#    1220         if obj._clock in curclocks:
# -> 1221             obj.run()
#    1223 for c in curclocks:
#    1224     timestep, t, dt = self._clock_variables[c]
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\core\operations.py:101, in NetworkOperation.run(self)
#      99     self.function(self._clock.t)
#     100 else:
# --> 101     self.function()
#
# Cell In[4], line 42, in IZH_inh_modified2.<locals>.change_I()
#      40 @network_operation(dt=1*ms)
#      41 def change_I():
# ---> 42     G.I = fI
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\groups\neurongroup.py:903, in NeuronGroup.__setattr__(self, key, value)
#     897     raise TypeError(
#     898         f"Cannot link variable '{key}', it has to be marked "
#     899         "as a linked variable with '(linked)' in the model "
#     900         "equations."
#     901     )
#     902 else:
# --> 903     Group.__setattr__(self, key, value, level=1)
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\groups\group.py:456, in VariableOwner.__setattr__(self, name, val, level)
#     454         raise TypeError(f"Variable {name} is read-only.")
#     455     # Make the call X.var = ... equivalent to X.var[:] = ...
# --> 456     var.get_addressable_value_with_unit(name, self).set_item(
#     457         slice(None), val, level=level + 1
#     458     )
#     459 elif len(name) and name[-1] == "_" and name[:-1] in self.variables:
#     460     # no unit checking
#     461     var = self.variables[name[:-1]]
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\core\variables.py:964, in VariableView.set_item(self, item, value, level, namespace)
#     961 # Both index and values are strings, use a single code object do deal
#     962 # with this situation
#     963 if isinstance(value, str) and isinstance(item, str):
# --> 964     self.set_with_expression_conditional(
#     965         item, value, check_units=check_units, run_namespace=namespace
#     966     )
#     967 elif isinstance(item, str):
#     968     try:
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\core\base.py:335, in device_override.<locals>.device_override_decorator.<locals>.device_override_decorated_function(*args, **kwds)
#     333     return getattr(curdev, name)(*args, **kwds)
#     334 else:
# --> 335     return func(*args, **kwds)
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\core\variables.py:1129, in VariableView.set_with_expression_conditional(self, cond, code, run_namespace, check_units)
#    1126 from brian2.devices.device import get_device
#    1128 device = get_device()
# -> 1129 codeobj = create_runner_codeobj(
#    1130     self.group,
#    1131     {"condition": abstract_code_cond, "statement": abstract_code},
#    1132     "group_variable_set_conditional",
#    1133     additional_variables=variables,
#    1134     check_units=check_units,
#    1135     run_namespace=run_namespace,
#    1136     codeobj_class=device.code_object_class(
#    1137         fallback_pref="codegen.string_expression_target"
#    1138     ),
#    1139 )
#    1140 codeobj()
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\codegen\codeobject.py:471, in create_runner_codeobj(group, code, template_name, run_namespace, user_code, variable_indices, name, check_units, needed_variables, additional_variables, template_kwds, override_conditional_write, codeobj_class)
#     468     if var_index not in ("_idx", "0"):
#     469         variables[var_index] = all_variables[var_index]
# --> 471 return device.code_object(
#     472     owner=group,
#     473     name=name,
#     474     abstract_code=code,
#     475     variables=variables,
#     476     template_name=template_name,
#     477     variable_indices=all_variable_indices,
#     478     template_kwds=template_kwds,
#     479     codeobj_class=codeobj_class,
#     480     override_conditional_write=override_conditional_write,
#     481     compiler_kwds=compiler_kwds,
#     482 )
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\devices\device.py:346, in Device.code_object(self, owner, name, abstract_code, variables, template_name, variable_indices, codeobj_class, template_kwds, override_conditional_write, compiler_kwds)
#     339 logger.diagnostic(
#     340     f"{name} snippet (scalar):\n{indent(code_representation(scalar_code))}"
#     341 )
#     342 logger.diagnostic(
#     343     f"{name} snippet (vector):\n{indent(code_representation(vector_code))}"
#     344 )
# --> 346 code = template(
#     347     scalar_code,
#     348     vector_code,
#     349     owner=owner,
#     350     variables=variables,
#     351     codeobj_name=name,
#     352     variable_indices=variable_indices,
#     353     get_array_name=generator.get_array_name,
#     354     **template_kwds,
#     355 )
#     356 logger.diagnostic(f"{name} code:\n{indent(code_representation(code))}")
#     358 codeobj = codeobj_class(
#     359     owner,
#     360     code,
#    (...)
#     366     compiler_kwds=compiler_kwds,
#     367 )
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\codegen\templates.py:251, in CodeObjectTemplate.__call__(self, scalar_code, vector_code, **kwds)
#     249 kwds["scalar_code"] = scalar_code
#     250 kwds["vector_code"] = vector_code
# --> 251 module = self.template.make_module(kwds)
#     252 if len([k for k in module.__dict__ if not k.startswith("_")]):
#     253     return MultiTemplate(module)
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\jinja2\environment.py:1405, in Template.make_module(self, vars, shared, locals)
#    1398 """This method works like the :attr:`module` attribute when called
#    1399 without arguments but it will evaluate the template on every call
#    1400 rather than caching it.  It's also possible to provide
#    1401 a dict which is then used as context.  The arguments are the same
#    1402 as for the :meth:`new_context` method.
#    1403 """
#    1404 ctx = self.new_context(vars, shared, locals)
# -> 1405 return TemplateModule(self, ctx)
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\jinja2\environment.py:1535, in TemplateModule.__init__(self, template, context, body_stream)
#    1528     if context.environment.is_async:
#    1529         raise RuntimeError(
#    1530             "Async mode requires a body stream to be passed to"
#    1531             " a template module. Use the async methods of the"
#    1532             " API you are using."
#    1533         )
# -> 1535     body_stream = list(template.root_render_func(context))  # type: ignore
#    1537 self._body_stream = body_stream
#    1538 self.__dict__.update(context.get_exported())
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\brian2\codegen\runtime\numpy_rt\templates\group_variable_set_conditional.py_:12, in root(context, missing, environment)
#      10 # be applied, and to do this we want to vectorise over all the values,
#      11 # but we don't want to do the iterate all protocol, so we explicitly
# ---> 12 # set the idx to be slice(None)
#      13 # scalar code
#      14 _vectorisation_idx = 1
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\jinja2\environment.py:1010, in Environment.get_template(self, name, parent, globals)
#    1007 if parent is not None:
#    1008     name = self.join_path(name, parent)
# -> 1010 return self._load_template(name, globals)
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\jinja2\environment.py:960, in Environment._load_template(self, name, globals)
#     957 if self.cache is not None:
#     958     template = self.cache.get(cache_key)
#     959     if template is not None and (
# --> 960         not self.auto_reload or template.is_up_to_date
#     961     ):
#     962         # template.globals is a ChainMap, modifying it will only
#     963         # affect the template, not the environment globals.
#     964         if globals:
#     965             template.globals.update(globals)
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\jinja2\environment.py:1494, in Template.is_up_to_date(self)
#    1492 if self._uptodate is None:
#    1493     return True
# -> 1494 return self._uptodate()
#
# File ~\anaconda3\envs\syde552\Lib\site-packages\jinja2\loaders.py:352, in PackageLoader.get_source.<locals>.up_to_date()
#     351 def up_to_date() -> bool:
# --> 352     return os.path.isfile(p) and os.path.getmtime(p) == mtime
#
# File <frozen genericpath>:30, in isfile(path)
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(8, 3))

av_ISIs = []
for ISI in ISIs:
    av_ISIs.append(np.average(ISI))

plt.scatter(inh_vals, av_ISIs, color='k', marker='s')
plt.plot(inh_vals[:-2], av_ISIs[:-2], 'k--')
plt.xlim([0, None])
plt.xlabel('BAC (%)')
plt.ylabel('Average ISI (s)')

plt.savefig('outputs/final_model_avg_isi.png', bbox_inches='tight')
plt.show()
plt.close()
